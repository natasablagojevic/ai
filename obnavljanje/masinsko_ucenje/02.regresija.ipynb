# %%
import tensorflow as tf 
from tensorflow import keras 
from tensorflow.keras import layers, datasets, models 
import numpy as np 
import matplotlib.pyplot as plt 
import seaborn as sns
# Out:
# 2023-06-05 08:53:30.268643: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2023-06-05 08:53:39.880692: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2023-06-05 08:54:16.429888: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
height = np.array([4.0, 4.5, 5.0, 5.2, 5.4, 5.8, 6.1, 6.2, 6.4, 6.8])
weight = np.array([42, 44, 49, 55, 53, 58, 60, 64, 66, 69])

# %%
plt.scatter(height, weight, color='red', marker='X')

# %%
N = height.shape[0]
X = np.ones((N, 2))

# %%
X[:,1] = height

# %%
X
# Out:
# array([[1. , 4. ],
#        [1. , 4.5],
#        [1. , 5. ],
#        [1. , 5.2],
#        [1. , 5.4],
#        [1. , 5.8],
#        [1. , 6.1],
#        [1. , 6.2],
#        [1. , 6.4],
#        [1. , 6.8]])

# %%
Y = weight

# %%
W = np.linalg.inv(X.T.dot(X)).dot(X.T).dot(Y)
W
# Out:
# array([-0.47266515, 10.19362187])

# %%
x1 = height[0]
x2 = height[N-1]

y1 = W[0] + W[1]*x1 
y2 = W[0] + W[1]*x2

# %%
plt.scatter(height, weight, color='red', marker='X')
plt.plot([x1, x2], [y1, y2], color='blue')

# %%
from sklearn import linear_model

# %%
lin_reg = linear_model.LinearRegression()

# %%
lin_reg.fit(height.reshape(-1, 1), weight)
# Out:
# LinearRegression()

# %%
lin_reg.coef_
# Out:
# array([10.19362187])

# %%
lin_reg.intercept_
# Out:
# -0.4726651480637756
